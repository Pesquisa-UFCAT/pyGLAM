# %%
from pyglam import *

# %%
import matplotlib.pyplot as plot

# %%
g = GlamFKML(lam1=0.00251029, lam2=(1.45848339*2), lam3=2, lam4=0.13239563)
x = g.rvs(size=1000)

plot.hist(x, bins=30, density=True)
plot.show()

# %%
g.ppf(0.00)
# Out:
# -5.064159411699556
